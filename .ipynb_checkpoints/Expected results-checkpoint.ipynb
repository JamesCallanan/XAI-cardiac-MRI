# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(15,10))
plt.rcParams.update({'font.size': 25})
plt.bar(['Low EF','High EF','weight'], [0.8,0.3,0.9],color='#003f5c')
plt.title("TCAV for Hypertension")
plt.ylabel("TCAV score")
plt.box("off")
plt.show()
